# %% [markdown]
# # **1. Agile is best described as:**
#
# A. Fixed step-by-step process
#
# B. Heavy documentation process
#
# C. Iterative and flexible development approach
#
# D. Hardware optimization method
#
# **Answer: C**
#
# # **2. Which scenario is BEST for Spiral model?**
#
# A. Small startup MVP
#
# B. High-risk system with unclear requirements
#
# C. Static website
#
# D. Simple CRUD app
#
# **Answer: B**
#
# # **3. Kanban primarily focuses on:**
#
# A. Fixed sprints
#
# B. Continuous workflow
#
# C. Heavy documentation
#
# D. Model training
#
# **Answer: B**
#
# # **4. Scrum uses:**
#
# A. Continuous deployment only
#
# B. Fixed time-boxed iterations (sprints)
#
# C. No planning
#
# D. Random task assignment
#
# **Answer: B**
#
# # **5. API versioning mainly ensures:**
#
# A. Faster database queries
#
# B. Backward compatibility
#
# C. UI design improvement
#
# D. Code compression
#
# **Answer: B**
#
# # **6. Which testing type ensures new changes don’t break old functionality?**
#
# A. Unit testing
#
# B. Regression testing
#
# C. Load testing
#
# D. Stress testing
#
# **Answer: B**
#
# # **7. Integration testing focuses on:**
#
# A. UI design
#
# B. Individual functions
#
# C. Interaction between modules
#
# D. Model accuracy
#
# **Answer: C**
#
# # **8. System testing validates:**
#
# A. One function only
#
# B. Entire system end-to-end
#
# C. Database schema only
#
# D. Code syntax
#
# **Answer: B**
#
# # **9. Which is NON-functional requirement?**
#
# A. Login system
#
# B. Payment feature
#
# C. System latency
#
# D. User signup
#
# **Answer: C**
#
# # **10. Software documentation helps mainly in:**
#
# A. Increasing CPU speed
#
# B. Knowledge sharing and maintainability
#
# C. UI rendering
#
# D. Database encryption
#
# **Answer: B**
#
# # **11. PR review happens:**
#
# A. Before writing code
#
# B. After deployment
#
# C. Before merging code
#
# D. During user testing
#
# **Answer: C**
#
# # **12. Primary purpose of code reviews is:**
#
# A. Increase code length
#
# B. Improve quality and catch bugs
#
# C. Slow development
#
# D. Replace testing
#
# **Answer: B**
#
# # **13. QA primarily ensures:**
#
# A. Faster UI design
#
# B. No regressions in system
#
# C. Better hardware
#
# D. AI model training
#
# **Answer: B**
#
# # **14. Which role defines system architecture?**
#
# A. QA Engineer
#
# B. Software Architect
#
# C. Data Entry Operator
#
# D. Support Engineer
#
# **Answer: B**
#
# # **15. DevOps focuses on:**
#
# A. UI design only
#
# B. Development + Operations automation
#
# C. Marketing
#
# D. Manual testing only
#
# **Answer: B**
#
# # **16. Which role is MOST responsible for production deployment?**
#
# A. Frontend Developer
#
# B. DevOps Engineer
#
# C. Product Manager
#
# D. UX Designer
#
# **Answer: B**
#
# # **17. In Agile teams, user stories represent:**
#
# A. Entire system
#
# B. Small user-focused requirements
#
# C. Database schema
#
# D. Infrastructure setup
#
# **Answer: B**
#
# # **18. Software versioning helps in:**
#
# A. Slower deployment
#
# B. Managing changes over time
#
# C. Increasing bugs
#
# D. Removing testing
#
# **Answer: B**
#
# # **19. Which is TRUE about Lean development?**
#
# A. Add maximum features
#
# B. Focus on eliminating waste
#
# C. Ignore feedback
#
# D. Delay delivery
#
# **Answer: B**
#
# # **20. Which team member is MOST responsible for defining “what to build”?**
#
# A. Developer
#
# B. QA Engineer
#
# C. Product Manager
#
# D. DevOps Engineer
#
# **Answer: C**
